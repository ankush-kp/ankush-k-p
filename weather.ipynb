# %% [markdown]
# <a href="https://colab.research.google.com/github/ankush-kp/ankush-k-p/blob/master/weather.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d7ee3053-47f0-4ea9-9052-9dfac9914b4a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d7ee3053-47f0-4ea9-9052-9dfac9914b4a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as numpyInstance
import pandas as pandasInstance
import matplotlib.pyplot as matplotlibInstance
import seaborn as seabornInstance

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MinTemp        366 non-null    float64
#  1   MaxTemp        366 non-null    float64
#  2   Rainfall       366 non-null    float64
#  3   Evaporation    366 non-null    float64
#  4   Sunshine       363 non-null    float64
#  5   WindGustDir    363 non-null    object
#  6   WindGustSpeed  364 non-null    float64
#  7   WindDir9am     335 non-null    object
#  8   WindDir3pm     365 non-null    object
#  9   WindSpeed9am   359 non-null    float64
#  10  WindSpeed3pm   366 non-null    int64
#  11  Humidity9am    366 non-null    int64
#  12  Humidity3pm    366 non-null    int64
#  13  Pressure9am    366 non-null    float64
#  14  Pressure3pm    366 non-null    float64
#  15  Cloud9am       366 non-null    int64
#  16  Cloud3pm       366 non-null    int64
# ...

# %%
weather.describe()
# Out:
#           MinTemp     MaxTemp    Rainfall  Evaporation    Sunshine  \
# count  366.000000  366.000000  366.000000   366.000000  363.000000
# mean     7.265574   20.550273    1.428415     4.521858    7.909366
# std      6.025800    6.690516    4.225800     2.669383    3.481517
# min     -5.300000    7.600000    0.000000     0.200000    0.000000
# 25%      2.300000   15.025000    0.000000     2.200000    5.950000
# 50%      7.450000   19.650000    0.000000     4.200000    8.600000
# 75%     12.500000   25.500000    0.200000     6.400000   10.500000
# max     20.900000   35.800000   39.800000    13.800000   13.600000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# count     364.000000    359.000000    366.000000   366.000000   366.000000
# mean       39.840659      9.651811     17.986339    72.035519    44.519126
# std        13.059807      7.951929      8.856997    13.137058    16.850947
# ...

# %%
seabornInstance.scatterplot(x='Temp3pm', y='Humidity3pm',data=weather)
# Out:
# <Axes: xlabel='Temp3pm', ylabel='Humidity3pm'>

# %%
seabornInstance.jointplot(x='Temp3pm', y='Humidity3pm',data=weather,kind='hex')

# %%
seabornInstance.lmplot(x='Temp3pm', y='Humidity3pm',data=weather)

# %%
matplotlibInstance.figure(figsize=(14,10))
matplotlibInstance.tight_layout()
seabornInstance.distplot(weather['Temp3pm'])
# Out:
# /tmp/ipython-input-2373779340.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   seabornInstance.distplot(weather['Temp3pm'])
# <Axes: xlabel='Temp3pm', ylabel='Density'>

# %%
matplotlibInstance.figure(figsize=(14,10))
matplotlibInstance.tight_layout()
seabornInstance.distplot(weather['Humidity3pm'])
# Out:
# /tmp/ipython-input-506017634.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   seabornInstance.distplot(weather['Humidity3pm'])
# <Axes: xlabel='Humidity3pm', ylabel='Density'>

# %%
matplotlibInstance.figure(figsize=(14,10))
matplotlibInstance.tight_layout()
seabornInstance.heatmap(numeric_weather.corr(), annot=True)
# Out:
# <Axes: >

# %%
X_Features = weather[['Humidity9am']]

# %%
X_Features
# Out:
#      Humidity9am
# 0             68
# 1             80
# 2             82
# 3             62
# 4             68
# ..           ...
# 361           38
# 362           45
# 363           63
# 364           69
# 365           43
#
# [366 rows x 1 columns]

# %%
Y_Prediction =weather[['Temp9am']]

# %%
Y_Prediction
# Out:
#      Temp9am
# 0       14.4
# 1       17.5
# 2       15.4
# 3       13.5
# 4       11.1
# ..       ...
# 361     20.4
# 362     17.2
# 363     14.5
# 364     15.8
# 365     23.8
#
# [366 rows x 1 columns]

# %%
matplotlibInstance.sctter()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1581170068.py in <cell line: 0>()
# ----> 1 temperaturePredictions = linearRegressionInstance.predict(X_Features)
#
# NameError: name 'linearRegressionInstance' is not defined
